# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
datadir = 'plot/'

# %%
filenames=os.listdir(datadir)
filenames
# Out:
# ['numRounds_10000_WinLossRate_alpha_0.0_gamma_0.8_learning_false_epsilon_0.8DReward10.txt',
#  'numRounds_10000_WinLossRate_alpha_0.0_gamma_0.8_learning_true_epsilon_0.8DReward10.txt',
#  'numRounds_10000_WinLossRate_alpha_0.5_gamma_0.8_learning_false_epsilon_0.8DReward10.txt',
#  'numRounds_10000_WinLossRate_alpha_0.5_gamma_0.8_learning_true_epsilon_0.8DReward10.txt']

# %%
df = pd.read_csv(datadir + filenames[2] ,  index_col=False, skiprows=1, header = None, delimiter = "\t\t")
df1 =  pd.read_csv(datadir + filenames[3] ,  index_col=False, skiprows=1, header = None, delimiter = "\t\t")
# Out:
# C:\Users\monst\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# C:\Users\monst\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
rate = df[1000:1002]
df = df[0:1000]
rate1 = df1[1000:1002]
df1 = df1[0:1000]
df1
# Out:
#         0      1      2
# 0       0  0.000  0.900
# 1      10  0.150  0.800
# 2      20  0.100  0.867
# 3      30  0.075  0.900
# 4      40  0.100  0.880
# ..    ...    ...    ...
# 995  9950  0.060  0.948
# 996  9960  0.060  0.948
# 997  9970  0.060  0.947
# 998  9980  0.060  0.948
# 999  9990  0.060  0.948
#
# [1000 rows x 3 columns]

# %%
fig = plt.figure(figsize = (25,12))
plt.title("Part 2(a) - Measure of progress " + " while Learning " + list(rate1[0].iloc[[0]])[0]+ "after Learning " + list(rate[0].iloc[[0]])[0],fontsize=24  )
plt.tick_params(axis='x', labelsize='small',labelrotation=90,pad=1)
plt.xlabel('Rounds',fontsize=18)
plt.ylabel('Win Rate (%)',fontsize=18)
ax = plt.subplot(111)
ax.plot(df[0],100*df[1], label = 'WhileTraining')
ax.plot(df1[0],100*df1[1], label = 'AfterTraining')
max_xticks = 100
xloc = plt.MaxNLocator(max_xticks)
ax.xaxis.set_major_locator(xloc)
ax.legend()
plt.savefig("Part2-a.png")
plt.show()
# Out:
# C:\Users\monst\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
